# %%
quarto的特点：（可以直接用于汇报）
自动运行全部内容（代码、文本、图表）

# %%
import re
m = re.search(r"\.csv$", "Listings.csv")

if m:
    print("是CSV文件")
else:
    print("不是CSV文件")
# Out:
# 是CSV文件

# %%
import re
re.search(r"\d$", "Room 101")
# Out:
# <re.Match object; span=(7, 8), match='1'>
